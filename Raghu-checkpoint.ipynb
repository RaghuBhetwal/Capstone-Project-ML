# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt 
import numpy as np

# %% [markdown]
# ## Reading the dataset

# %%
result_data = pd.read_csv('results.csv')
status_data = pd.read_csv('status.csv')
drivers_data = pd.read_csv('drivers.csv')
races_data = pd.read_csv('races.csv')
constructors_data = pd.read_csv('constructors.csv')
driver_standings_data = pd.read_csv('driver_standings.csv')
pd.get_option("display.max_columns", None)
# Out:
# 20

# %%
result_data.head()
# Out:
#    resultId  raceId  driverId  constructorId number  grid position  \
# 0         1      18         1              1     22     1        1
# 1         2      18         2              2      3     5        2
# 2         3      18         3              3      7     7        3
# 3         4      18         4              4      5    11        4
# 4         5      18         5              1     23     3        5
#
#   positionText  positionOrder  points  laps         time milliseconds  \
# 0            1              1    10.0    58  1:34:50.616      5690616
# 1            2              2     8.0    58       +5.478      5696094
# 2            3              3     6.0    58       +8.163      5698779
# 3            4              4     5.0    58      +17.181      5707797
# 4            5              5     4.0    58      +18.014      5708630
#
#   fastestLap rank fastestLapTime fastestLapSpeed  statusId
# 0         39    2       1:27.452         218.300         1
# ...

# %%
status_data.head()
# Out:
#    statusId        status
# 0         1      Finished
# 1         2  Disqualified
# 2         3      Accident
# 3         4     Collision
# 4         5        Engine

# %%
status_data.columns
# Out:
# Index(['statusId', 'status'], dtype='object')

# %%
drivers_data.head()
# Out:
#    driverId   driverRef number code  forename     surname         dob  \
# 0         1    hamilton     44  HAM     Lewis    Hamilton  1985-01-07
# 1         2    heidfeld     \N  HEI      Nick    Heidfeld  1977-05-10
# 2         3     rosberg      6  ROS      Nico     Rosberg  1985-06-27
# 3         4      alonso     14  ALO  Fernando      Alonso  1981-07-29
# 4         5  kovalainen     \N  KOV    Heikki  Kovalainen  1981-10-19
#
#   nationality                                             url
# 0     British     http://en.wikipedia.org/wiki/Lewis_Hamilton
# 1      German      http://en.wikipedia.org/wiki/Nick_Heidfeld
# 2      German       http://en.wikipedia.org/wiki/Nico_Rosberg
# 3     Spanish    http://en.wikipedia.org/wiki/Fernando_Alonso
# 4     Finnish  http://en.wikipedia.org/wiki/Heikki_Kovalainen

# %%
races_data.head(3)
# Out:
#    raceId  year  round  circuitId                   name        date  \
# 0       1  2009      1          1  Australian Grand Prix  2009-03-29
# 1       2  2009      2          2   Malaysian Grand Prix  2009-04-05
# 2       3  2009      3         17     Chinese Grand Prix  2009-04-19
#
#        time                                                url fp1_date  \
# 0  06:00:00  http://en.wikipedia.org/wiki/2009_Australian_G...       \N
# 1  09:00:00  http://en.wikipedia.org/wiki/2009_Malaysian_Gr...       \N
# 2  07:00:00  http://en.wikipedia.org/wiki/2009_Chinese_Gran...       \N
#
#   fp1_time fp2_date fp2_time fp3_date fp3_time quali_date quali_time  \
# 0       \N       \N       \N       \N       \N         \N         \N
# 1       \N       \N       \N       \N       \N         \N         \N
# 2       \N       \N       \N       \N       \N         \N         \N
#
#   sprint_date sprint_time
# 0          \N          \N
# 1          \N          \N
# 2          \N          \N

# %%
constructors_data.head(3)
# Out:
#    constructorId constructorRef        name nationality  \
# 0              1        mclaren     McLaren     British
# 1              2     bmw_sauber  BMW Sauber      German
# 2              3       williams    Williams     British
#
#                                                  url
# 0               http://en.wikipedia.org/wiki/McLaren
# 1            http://en.wikipedia.org/wiki/BMW_Sauber
# 2  http://en.wikipedia.org/wiki/Williams_Grand_Pr...

# %%
driver_standings_data.head()
# Out:
#    driverStandingsId  raceId  driverId  points  position positionText  wins
# 0                  1      18         1    10.0         1            1     1
# 1                  2      18         2     8.0         2            2     0
# 2                  3      18         3     6.0         3            3     0
# 3                  4      18         4     5.0         4            4     0
# 4                  5      18         5     4.0         5            5     0

# %%
merged_data_1 = pd.merge(result_data, races_data, on='raceId')
merged_data_2 = pd.merge(merged_data_1, drivers_data, on='driverId')
merged_data_3 = pd.merge(merged_data_2, driver_standings_data, on='driverId')
merged_data_4 = pd.merge(merged_data_3, constructors_data, on='constructorId')
df = pd.merge(merged_data_4, status_data, on='statusId')
df.head()
# Out:
#    resultId  raceId_x  driverId  constructorId number_x  grid position_x  \
# 0         1        18         1              1       22     1          1
# 1         1        18         1              1       22     1          1
# 2         1        18         1              1       22     1          1
# 3         1        18         1              1       22     1          1
# 4         1        18         1              1       22     1          1
#
#   positionText_x  positionOrder  points_x  ...  raceId_y points_y position_y  \
# 0              1              1      10.0  ...        18     10.0          1
# 1              1              1      10.0  ...        19     14.0          1
# 2              1              1      10.0  ...        20     14.0          3
# 3              1              1      10.0  ...        21     20.0          2
# 4              1              1      10.0  ...        22     28.0          3
#
#   positionText_y wins constructorRef   name_y  nationality_y  \
# ...

# %%
df.columns
# Out:
# Index(['resultId', 'raceId_x', 'driverId', 'constructorId', 'number_x', 'grid',
#        'position_x', 'positionText_x', 'positionOrder', 'points_x', 'laps',
#        'time_x', 'milliseconds', 'fastestLap', 'rank', 'fastestLapTime',
#        'fastestLapSpeed', 'statusId', 'year', 'round', 'circuitId', 'name_x',
#        'date', 'time_y', 'url_x', 'fp1_date', 'fp1_time', 'fp2_date',
#        'fp2_time', 'fp3_date', 'fp3_time', 'quali_date', 'quali_time',
#        'sprint_date', 'sprint_time', 'driverRef', 'number_y', 'code',
#        'forename', 'surname', 'dob', 'nationality_x', 'url_y',
#        'driverStandingsId', 'raceId_y', 'points_y', 'position_y',
#        'positionText_y', 'wins', 'constructorRef', 'name_y', 'nationality_y',
#        'url', 'status'],
#       dtype='object')

# %%
df.shape
# Out:
# (3475793, 54)

# %%
# Select relevant features and target variable
# relevant_columns = ['grid', 'position_x', 'laps', 'fastestLap', 'rank', 'circuitId']
relevant_columns = ['grid',"points_x", 'position_x', 'laps', 'fastestLap', 'rank', 'circuitId', 'driverId', 'constructorId', 'year', 'statusId']
df_selected = df[relevant_columns]
X = df[relevant_columns]
y = df['points_x']

# %%
# Check for missing values
missing_values = df_selected.isnull().sum()
print(missing_values)
# Out:
# grid             0
# points_x         0
# position_x       0
# laps             0
# fastestLap       0
# rank             0
# circuitId        0
# driverId         0
# constructorId    0
# year             0
# statusId         0
# dtype: int64

# %%
# Check for duplicate rows
duplicates = df.duplicated()
duplicate_rows = df[duplicates]
print("Number of duplicate rows:", duplicate_rows.shape[0])
# Out:
# Number of duplicate rows: 0

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.scatterplot(x='position_x', y='points_x', data=df_selected)
plt.xlabel('Position')
plt.ylabel('Points')
plt.title('Points Achieved by Position')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Compute correlation matrix
corr_matrix = df_selected.corr()

# Plot correlation matrix as a heatmap with 'viridis' color palette
sns.heatmap(corr_matrix, annot=True, cmap='viridis')
plt.title('Correlation Matrix')
plt.show()

# %%
sns.lineplot(x='year', y='points_x', data=df_selected)
plt.xlabel('Year')
plt.ylabel('Points')
plt.title('Points Achieved Over Time')
plt.show()

# %%
sns.lineplot(x='year', y='points_x', data=df_selected)
plt.xlabel('Year')
plt.ylabel('Points')
plt.title('Points Achieved Over Time')
plt.show()

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# Select relevant features and target variable
relevant_columns = ['grid', 'points_x', 'position_x', 'laps', 'fastestLap', 'rank']
df_selected = df[relevant_columns].copy()

# Handle missing values
df_selected = df_selected.replace('\\N', np.nan)

# Drop rows with missing values
df_selected.dropna(inplace=True)

# Separate features and target variable
X = df_selected.drop('points_x', axis=1)
y = df_selected['points_x']

# Apply Min-Max scaling to the features
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# Split the data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Print the shapes of the train and test sets
print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_train shape: (918821, 5)
# X_test shape: (229706, 5)
# y_train shape: (918821,)
# y_test shape: (229706,)

# %%
###COde
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.tree import DecisionTreeRegressor
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error, r2_score
from math import sqrt
from tabulate import tabulate

# Train the XGBoost model
xgb = XGBRegressor()
xgb.fit(X_train, y_train)
xgb_train_predictions = xgb.predict(X_train)
xgb_train_rmse = sqrt(mean_squared_error(y_train, xgb_train_predictions))
xgb_train_r2 = r2_score(y_train, xgb_train_predictions)
xgb_train_adjusted_r2 = 1 - (1 - xgb_train_r2) * (len(X_train) - 1) / (len(X_train) - X_train.shape[1] - 1)

xgb_test_predictions = xgb.predict(X_test)
xgb_test_rmse = sqrt(mean_squared_error(y_test, xgb_test_predictions))
xgb_test_r2 = r2_score(y_test, xgb_test_predictions)
xgb_test_adjusted_r2 = 1 - (1 - xgb_test_r2) * (len(X_test) - 1) / (len(X_test) - X_test.shape[1] - 1)

# Train the Random Forest model
rf = RandomForestRegressor()
rf.fit(X_train, y_train)
rf_train_predictions = rf.predict(X_train)
rf_train_rmse = sqrt(mean_squared_error(y_train, rf_train_predictions))
rf_train_r2 = r2_score(y_train, rf_train_predictions)
rf_train_adjusted_r2 = 1 - (1 - rf_train_r2) * (len(X_train) - 1) / (len(X_train) - X_train.shape[1] - 1)

rf_test_predictions = rf.predict(X_test)
rf_test_rmse = sqrt(mean_squared_error(y_test, rf_test_predictions))
rf_test_r2 = r2_score(y_test, rf_test_predictions)
rf_test_adjusted_r2 = 1 - (1 - rf_test_r2) * (len(X_test) - 1) / (len(X_test) - X_test.shape[1] - 1)

# Train the Gradient Boosting model
gb = GradientBoostingRegressor()
gb.fit(X_train, y_train)
gb_train_predictions = gb.predict(X_train)
gb_train_rmse = sqrt(mean_squared_error(y_train, gb_train_predictions))
gb_train_r2 = r2_score(y_train, gb_train_predictions)
gb_train_adjusted_r2 = 1 - (1 - gb_train_r2) * (len(X_train) - 1) / (len(X_train) - X_train.shape[1] - 1)

gb_test_predictions = gb.predict(X_test)
gb_test_rmse = sqrt(mean_squared_error(y_test, gb_test_predictions))
gb_test_r2 = r2_score(y_test, gb_test_predictions)
gb_test_adjusted_r2 = 1 - (1 - gb_test_r2) * (len(X_test) - 1) / (len(X_test) - X_test.shape[1] - 1)

# Train the Decision Tree model
dt = DecisionTreeRegressor()
dt.fit(X_train, y_train)
dt_train_predictions = dt.predict(X_train)
dt_train_rmse = sqrt(mean_squared_error(y_train, dt_train_predictions))
dt_train_r2 = r2_score(y_train, dt_train_predictions)
dt_train_adjusted_r2 = 1 - (1 - dt_train_r2) * (len(X_train) - 1) / (len(X_train) - X_train.shape[1] - 1)

dt_test_predictions = dt.predict(X_test)
dt_test_rmse = sqrt(mean_squared_error(y_test, dt_test_predictions))
dt_test_r2 = r2_score(y_test, dt_test_predictions)
dt_test_adjusted_r2 = 1 - (1 - dt_test_r2) * (len(X_test) - 1) / (len(X_test) - X_test.shape[1] - 1)

# Create the table data
table_data = [
    ["Model", "Training RMSE", "Training R^2 Score", "Training Adjusted R^2", "Testing RMSE", "Testing R^2 Score", "Testing Adjusted R^2"],
    ["XGBoost", xgb_train_rmse, xgb_train_r2, xgb_train_adjusted_r2, xgb_test_rmse, xgb_test_r2, xgb_test_adjusted_r2],
    ["Random Forest", rf_train_rmse, rf_train_r2, rf_train_adjusted_r2, rf_test_rmse, rf_test_r2, rf_test_adjusted_r2],
    ["Gradient Boosting", gb_train_rmse, gb_train_r2, gb_train_adjusted_r2, gb_test_rmse, gb_test_r2, gb_test_adjusted_r2],
    ["Decision Tree", dt_train_rmse, dt_train_r2, dt_train_adjusted_r2, dt_test_rmse, dt_test_r2, dt_test_adjusted_r2]
]

# Print the table
table = tabulate(table_data, headers="firstrow", tablefmt="grid")
print(table)
# Out:
# +-------------------+-----------------+----------------------+-------------------------+----------------+---------------------+------------------------+
# | Model             |   Training RMSE |   Training R^2 Score |   Training Adjusted R^2 |   Testing RMSE |   Testing R^2 Score |   Testing Adjusted R^2 |
# +===================+=================+======================+=========================+================+=====================+========================+
# | XGBoost           |        0.993895 |             0.981409 |                0.981409 |       0.994372 |            0.981504 |               0.981503 |
# +-------------------+-----------------+----------------------+-------------------------+----------------+---------------------+------------------------+
# | Random Forest     |        0.259698 |             0.998731 |                0.998731 |       0.26007  |            0.998735 |               0.998735 |
# ...

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, LSTM, Dense, Flatten
from sklearn.metrics import mean_squared_error, r2_score
from math import sqrt
from tabulate import tabulate

# Reshape the input data for CNNLSTM
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# Build the CNNLSTM model
model = Sequential()
model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(X_train.shape[1], 1)))
model.add(LSTM(units=64, activation='relu'))
model.add(Dense(units=1))

# Compile and train the model
model.compile(optimizer='adam', loss='mse')
model.fit(X_train, y_train, epochs=10, batch_size=32)

# Generate predictions for training and testing data
train_predictions = model.predict(X_train)
test_predictions = model.predict(X_test)

# Calculate evaluation metrics for training data
train_rmse = sqrt(mean_squared_error(y_train, train_predictions))
train_r2 = r2_score(y_train, train_predictions)
train_adjusted_r2 = 1 - (1 - train_r2) * (len(X_train) - 1) / (len(X_train) - X_train.shape[1] - 1)

# Calculate evaluation metrics for testing data
test_rmse = sqrt(mean_squared_error(y_test, test_predictions))
test_r2 = r2_score(y_test, test_predictions)
test_adjusted_r2 = 1 - (1 - test_r2) * (len(X_test) - 1) / (len(X_test) - X_test.shape[1] - 1)

# Create the table data
table_data = [
    ["Model", "Training RMSE", "Training R^2 Score", "Training Adjusted R^2", "Testing RMSE", "Testing R^2 Score", "Testing Adjusted R^2"],
    ["CNNLSTM", train_rmse, train_r2, train_adjusted_r2, test_rmse, test_r2, test_adjusted_r2],
]

# Print the table
table = tabulate(table_data, headers="firstrow", tablefmt="grid")
print(table)
# Out:
# Epoch 1/10
# 28714/28714 [==============================] - 79s 3ms/step - loss: 7.5279
# Epoch 2/10
# 28714/28714 [==============================] - 73s 3ms/step - loss: 6.1796
# Epoch 3/10
# 28714/28714 [==============================] - 75s 3ms/step - loss: 5.4425
# Epoch 4/10
# 28714/28714 [==============================] - 75s 3ms/step - loss: 4.5307
# Epoch 5/10
# 28714/28714 [==============================] - 72s 3ms/step - loss: 3.3585
# Epoch 6/10
# 28714/28714 [==============================] - 76s 3ms/step - loss: 2.3901
# Epoch 7/10
# 28714/28714 [==============================] - 72s 3ms/step - loss: 1.7300
# Epoch 8/10
# 28714/28714 [==============================] - 71s 2ms/step - loss: 1.2787
# Epoch 9/10
# 28714/28714 [==============================] - 77s 3ms/step - loss: 0.9793
# Epoch 10/10
# ...
# 7179/7179 [==============================] - 11s 1ms/step
# ...

# %%
# Create scatter plots for testing data
plt.figure(figsize=(10, 6))

# XGBoost scatter plot
plt.scatter(y_test, xgb_test_predictions, color='red', label='XGBoost')
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='blue', linestyle='--')
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('XGBoost: Actual vs Predicted Outputs (Testing Data)')
plt.legend()
plt.show()

# Random Forest scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(y_test, rf_test_predictions, color='green', label='Random Forest')
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='blue', linestyle='--')
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Random Forest: Actual vs Predicted Outputs (Testing Data)')
plt.legend()
plt.show()

# Gradient Boosting scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(y_test, gb_test_predictions, color='orange', label='Gradient Boosting')
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='blue', linestyle='--')
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Gradient Boosting: Actual vs Predicted Outputs (Testing Data)')
plt.legend()
plt.show()

# Decision Tree scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(y_test, dt_test_predictions, color='purple', label='Decision Tree')
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='blue', linestyle='--')
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Decision Tree: Actual vs Predicted Outputs (Testing Data)')
plt.legend()
plt.show()

# %%
# Create scatter plot for testing data
plt.figure(figsize=(10, 6))
plt.scatter(y_test, test_predictions, color='purple', label='CNNLSTM')
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='blue', linestyle='--')
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('CNNLSTM: Actual vs Predicted Outputs (Testing Data)')
plt.legend()
plt.show()

# %%
# Create a list of model names and their corresponding R2 scores
model_names = ['XGBoost', 'Random Forest', 'Gradient Boosting', 'Decision Tree', 'CNNLSTM']
r2_scores = [xgb_test_r2, rf_test_r2, gb_test_r2, dt_test_r2, test_r2]

# Define a color palette
palette = sns.color_palette('Set1', len(model_names))

# Create an array of x-coordinates for the models
x_pos = np.arange(len(model_names))

# Plot the line chart with markers
sns.lineplot(x_pos, r2_scores, marker='o', palette=palette)

# Customize x-axis labels
plt.xticks(x_pos, model_names)

plt.xlabel('Model')
plt.ylabel('R2 Score')
plt.title('Accuracy Comparison of Different Models')

plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
